# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/ADMIN/PycharmProjects/CDTN/place_info.csv')
df
# Out:
#                                                    url  \
# 0    https://www.google.com/maps/place/Si%C3%AAu+th...
# 1    https://www.google.com/maps/place/Si%C3%AAu+Th...
# 2    https://www.google.com/maps/place/M%E1%BA%B9+v...
# 3    https://www.google.com/maps/place/Si%C3%AAu+Th...
# 4    https://www.google.com/maps/place/Nana%27s+Hou...
# ..                                                 ...
# 172  https://www.google.com/maps/place/H%E1%BB%87+t...
# 173  https://www.google.com/maps/place/C%E1%BB%ADa+...
# 174  https://www.google.com/maps/place/Kidsplaza+41...
# 175  https://www.google.com/maps/place/Si%C3%AAu+th...
# 176  https://www.google.com/maps/place/Si%C3%AAu+th...
#
#                                                   name  \
# 0                        Siêu thị mẹ và bé Violet Pham
# 1              Siêu Thị Mẹ Và Bé OVmart - Lê Trọng Tấn
# 2                                             Mẹ và Bé
# 3                           Siêu Thị Mẹ Và Bé Baby Kid
# ...

# %%
df.duplicated().sum()
# Out:
# 29

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
#                                                    url  \
# 85   https://www.google.com/maps/place/H%E1%BB%87+T...
# 86   https://www.google.com/maps/place/H%E1%BB%87+T...
# 88   https://www.google.com/maps/place/H%E1%BB%87+T...
# 94   https://www.google.com/maps/place/H%E1%BB%87+T...
# 95   https://www.google.com/maps/place/H%E1%BB%87+T...
# 106  https://www.google.com/maps/place/H%E1%BB%87+T...
# 129  https://www.google.com/maps/place/Bibomart+Ngu...
# 130  https://www.google.com/maps/place/Si%C3%AAu+th...
# 136  https://www.google.com/maps/place/Si%C3%AAu+th...
# 138  https://www.google.com/maps/place/Si%C3%AAu+th...
# 139  https://www.google.com/maps/place/Kids+Plaza/d...
# 140  https://www.google.com/maps/place/Si%C3%AAu+th...
# 141  https://www.google.com/maps/place/Si%C3%AAu+th...
# 142  https://www.google.com/maps/place/Si%C3%AAu+th...
# 146  https://www.google.com/maps/place/Kids+Plaza+N...
# 147  https://www.google.com/maps/place/Si%C3%AAu+th...
# ...

# %%
df.drop_duplicates(inplace=True,)
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                                                    url  \
# 0    https://www.google.com/maps/place/Si%C3%AAu+th...
# 1    https://www.google.com/maps/place/Si%C3%AAu+Th...
# 2    https://www.google.com/maps/place/M%E1%BA%B9+v...
# 3    https://www.google.com/maps/place/Si%C3%AAu+Th...
# 4    https://www.google.com/maps/place/Nana%27s+Hou...
# ..                                                 ...
# 169  https://www.google.com/maps/place/Kids+Plaza+S...
# 171  https://www.google.com/maps/place/%C4%90%E1%BB...
# 172  https://www.google.com/maps/place/H%E1%BB%87+t...
# 173  https://www.google.com/maps/place/C%E1%BB%ADa+...
# 174  https://www.google.com/maps/place/Kidsplaza+41...
#
#                                                   name  \
# 0                        Siêu thị mẹ và bé Violet Pham
# 1              Siêu Thị Mẹ Và Bé OVmart - Lê Trọng Tấn
# 2                                             Mẹ và Bé
# 3                           Siêu Thị Mẹ Và Bé Baby Kid
# ...

# %%
df.isnull().sum()
# Out:
# url           0
# name          0
# address       6
# status       11
# rating       20
# phone        24
# latitude      1
# longitude     1
# dtype: int64
